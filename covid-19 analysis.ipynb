# %% [markdown]
# # Mission 1

# %%
import pandas as pd
data = pd.read_csv("covid19.csv")

# %%
data.head(10)
# Out:
#    Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1  30/01/20               Kerala                        1
# 1    2  31/01/20               Kerala                        1
# 2    3  01/02/20               Kerala                        2
# 3    4  02/02/20               Kerala                        3
# 4    5  03/02/20               Kerala                        3
# 5    6  04/02/20               Kerala                        3
# 6    7  05/02/20               Kerala                        3
# 7    8  06/02/20               Kerala                        3
# 8    9  07/02/20               Kerala                        3
# 9   10  08/02/20               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# 4                         0      0       0
# ...

# %%
x = data.groupby('Date',sort=False)[['ConfirmedIndianNational','ConfirmedForeignNational','Cured','Deaths']].sum()

# %%
x['total sum'] = x.sum(axis=1)

# %%
x
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
x.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df1 = x.drop(['ConfirmedIndianNational','ConfirmedForeignNational','Cured','Deaths'],axis = 1)

# %%
rows = df1.loc["04/03/20":]
rows
# Out:
#           total sum
# Date
# 04/03/20         31
# 05/03/20         33
# 06/03/20         34
# 07/03/20         37
# 08/03/20         42
# 09/03/20         49
# 10/03/20         61
# 11/03/20         63
# 12/03/20         77
# 13/03/20         85
# 14/03/20         96
# 15/03/20        125
# 16/03/20        129
# 17/03/20        154
# 18/03/20        168
# 19/03/20        197
# 20/03/20        250
# 21/03/20        310

# %%
df2 = rows.pct_change()
df2
# Out:
#           total sum
# Date
# 04/03/20        NaN
# 05/03/20   0.064516
# 06/03/20   0.030303
# 07/03/20   0.088235
# 08/03/20   0.135135
# 09/03/20   0.166667
# 10/03/20   0.244898
# 11/03/20   0.032787
# 12/03/20   0.222222
# 13/03/20   0.103896
# 14/03/20   0.129412
# 15/03/20   0.302083
# 16/03/20   0.032000
# 17/03/20   0.193798
# 18/03/20   0.090909
# 19/03/20   0.172619
# 20/03/20   0.269036
# 21/03/20   0.240000

# %%
df2.mean()
# Out:
# total sum    0.148148
# dtype: float64
